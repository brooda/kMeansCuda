# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Create input file

# %%
lenOfInput = 10000000;

# %%
k = 3
k_centers = [(2, 2, 2), (6, 6, 6), (6, 6, 0)]

xs = []
ys = []
zs = []
classes = []

# %%
for i in range(k):
    centre = k_centers[i]
    xc = centre[0]
    yc = centre[1]
    zc = centre[2]
    
    
    for j in range(lenOfInput):
        deltax = np.random.normal()
        deltay = np.random.normal()
        deltaz = np.random.normal()

        xs.append(xc + deltax)
        ys.append(yc + deltay)
        zs.append(zc + deltaz)
        
xs = np.round(xs, 2)
ys = np.round(ys, 2)
zs = np.round(zs, 2)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(xs, ys, zs)

ax.set_xlim3d(-10, 10)
ax.set_ylim3d(-5, 10)
ax.set_zlim3d(-10, 10)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
df = pd.DataFrame({"x" : xs, "y" : ys, "z" : zs})

# %%
df.to_csv(f"{lenOfInput}.csv", index=False, header=False)

# %% [markdown]
# # Get results

# %%
colors= ['red' if l == 0 else 'green' if l==1 else 'blue' for l in labels]

# %%
colors
# Out:
# ['green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
# ...

# %%
len(colors)
# Out:
# 300

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(xs, ys, zs, color=colors)
ax.set_xlim3d(-10, 10)
ax.set_ylim3d(-10, 10)
ax.set_zlim3d(-10, 10)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
